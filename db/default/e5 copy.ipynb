# %% [markdown]
# # sec1 - 감사의견

# %% [markdown]
# ## chromadb 설정

# %%
import os, io, json, re, uuid, hashlib, textwrap
from typing import Any, Dict, List, Tuple

# Chroma 초기화 (영속 디렉터리 + 기본 임베딩)
import chromadb
from chromadb.utils import embedding_functions

# CHROMA_PERSIST_DIR:
# - 로컬 디스크에 벡터DB를 영속화합니다.
CHROMA_PERSIST_DIR = os.environ.get("CHROMA_DIR", "./chroma_db")
client = chromadb.PersistentClient(path=CHROMA_PERSIST_DIR)

# 생성/획득할 컬렉션 이름 (sec1 전용)
COLL_NAME = "sec1"

# get_or_create_collection:
# - 존재하면 가져오고, 없으면 생성.
# - embedding_function을 바인딩해 두면 add/query에서 자동 이용
sec1_col = client.get_or_create_collection(name=COLL_NAME)

# %% [markdown]
# ## 파일 경로 / 입출력 유틸

# %%
BASE = "../../json"
INPUT_PATH = os.path.join(BASE, "감사의견.jsonl")

def _strip_bom(s: str) -> str:
    """UTF-8 BOM이 있다면 제거합니다."""
    return s[1:] if s and s[0] == "\ufeff" else s

def read_json_or_jsonl(path: str) -> List[Dict[str, Any]]:
    """
    입력 파일을 JSON Array 또는 JSONL로 유연하게 읽습니다.
    - JSON 배열: [ {...}, {...}, ... ]
    - JSONL: 줄마다 하나의 JSON 객체
    - 공백/주석(//, #) 라인은 무시
    - 끝에 실수로 붙은 콤마(,) 제거
    """
    with open(path, "r", encoding="utf-8") as f:
        raw = _strip_bom(f.read()).strip()

    if not raw:
        return []

    # 1) 배열 JSON인지 먼저 감지
    if raw.startswith("["):
        return json.loads(raw)

    # 2) JSONL 처리
    items = []
    for line in io.StringIO(raw):
        line = line.strip()
        if not line or line.startswith("//") or line.startswith("#"):
            continue
        if line.endswith(","):  # 실수로 남은 trailing comma 제거
            line = line[:-1]
        items.append(json.loads(line))
    return items

def _pick_first(d: Dict[str, Any], keys, default=None):
    """
    키 후보 목록 중 첫 번째로 존재하는 값을 반환.
    - 서로 다른 스키마/표기(영문/국문) 혼용을 흡수하기 위해 사용.
    """
    for k in keys:
        if k in d and d[k] not in (None, ""):
            return d[k]
    return default

# %% [markdown]
# ## 청크화

# %%
def clean_text(s: str) -> str:
    if not s:
        return ""
    s = re.sub(r"(?i)<br\s*/?>", "\n", s)
    s = re.sub(r"(?i)</p\s*>", "\n", s)
    s = re.sub(r"(?i)<p\s*>", "", s)
    s = re.sub(r"<[^>]+>", " ", s)
    s = s.replace("\xa0", " ")
    s = re.sub(r"[ \t\f\v]+", " ", s)
    s = re.sub(r"\s*\n\s*", "\n", s)
    s = re.sub(r"\n{3,}", "\n\n", s)
    return s.strip()

def make_kam_document(rec: Dict[str, Any]) -> str:
    """
    KAM/감사보고 본문을 한 문서로 구성 (헤더+본문)
    - extra_meta 없음: 오직 텍스트만 생성
    """
    company = _pick_first(rec, ["company", "corp", "회사", "issuer", "entity"])
    year    = _pick_first(rec, ["year", "연도", "report_year", "date_year"])
    # 핵심 서술부(있을 수 있는 후보들을 최대한 흡수)
    body_main   = _pick_first(rec, ["kam_text", "kam", "text", "content", "body", "description"])
    body_reason = _pick_first(rec, ["reason", "배경", "핵심감사사항의_선정근거", "why_matter"])
    body_proc   = _pick_first(rec, ["response", "audit_response", "감사인의_대응", "감사절차", "procedures"])

    body_main   = clean_text(str(body_main)   if body_main   is not None else "")
    body_reason = clean_text(str(body_reason) if body_reason is not None else "")
    body_proc   = clean_text(str(body_proc)   if body_proc   is not None else "")

    header = " · ".join([str(x) for x in [company, year] if x])
    sections = []
    if body_main:   sections.append("【핵심감사사항】\n" + body_main)
    if body_reason: sections.append("【선정 사유/배경】\n" + body_reason)
    if body_proc:   sections.append("【감사인의 대응/절차】\n" + body_proc)

    full_text = "\n\n".join([p for p in [header, *sections] if p]).strip()
    return full_text

def chunk_text(text: str, max_chars: int = 1200, overlap: int = 150) -> List[str]:
    text = text.strip()
    if not text:
        return []
    chunks, start, n = [], 0, len(text)
    while start < n:
        end = min(start + max_chars, n)
        if end < n:
            window = text[start:end]
            cut = max(window.rfind("\n"), window.rfind("."))
            if cut >= 200:
                end = start + cut + 1
        chunks.append(text[start:end].strip())
        if end >= n:
            break
        start = max(0, end - overlap)
    return [c for c in chunks if c]

# %% [markdown]
# ## 메타데이터 빌드

# %%
def build_core_metadata(rec: Dict[str, Any], source_path: str) -> Dict[str, Any]:
    """
    오직 core 필드만!
    - company, year, section, section_path, section_name, source, _raw
    """
    company = _pick_first(rec, ["company", "corp", "회사", "issuer", "entity"])
    year    = _pick_first(rec, ["year", "연도", "report_year", "date_year"])

    # section 계층(문서 성격만 표기; downstream에서 필터링 용)
    # KAM/감사의견이 한 파일에 섞여 있을 수 있으므로, record에 명시 없으면 'sec1'로 통일
    section = _pick_first(rec, ["section", "섹션", "kind"]) or "sec1"
    # 보다 명확한 경로/라벨(있으면 쓰고 없으면 기본값)
    section_path = _pick_first(rec, ["section_path", "path"]) or "sec1/auditor_kam"
    section_name = _pick_first(rec, ["section_name", "name", "title"]) or "auditor_kam"

    return {
        "company": company,
        "year": year,
        "section": section,
        "section_path": section_path,
        "section_name": section_name,
        "source": source_path,
        "_raw": json.dumps(rec, ensure_ascii=False, separators=(",", ":")),
    }

def stable_doc_id(company, year, text: str) -> str:
    """extra_meta 없이 company/year/텍스트 일부로 안정 ID 생성"""
    key = f"{company}|{year}|{text[:200]}"
    return "sec1-" + hashlib.md5(key.encode("utf-8")).hexdigest()[:20]

# %% [markdown]
# ## upsert

# %%
def normalize_metadata(md: Dict[str, Any]) -> Dict[str, Any]:
    fixed = {}
    for k, v in md.items():
        if isinstance(v, list):
            # 리스트 → 콤마로 join
            fixed[k] = ", ".join(str(x) for x in v)
        elif isinstance(v, dict):
            # dict → JSON string
            fixed[k] = json.dumps(v, ensure_ascii=False)
        else:
            fixed[k] = v
    return fixed

# %%
def upsert_jsonl_direct(input_path: str, collection, batch_size: int = 1000):
    if not os.path.exists(input_path):
        print(f"[WARN] not found: {input_path}")
        return

    items = read_json_or_jsonl(input_path)
    if not items:
        print(f"[WARN] empty: {input_path}")
        return

    batch_ids, batch_docs, batch_mds = [], [], []
    for i, rec in enumerate(items):
        rid = rec.get("id") or f"row-{i}"
        doc = rec.get("document", "").strip()
        md  = rec.get("metadata", {})

        if not doc:
            continue

        # ⚡️ metadata 정규화
        md = normalize_metadata(md)

        batch_ids.append(rid)
        batch_docs.append(doc)
        batch_mds.append(md)

        if len(batch_ids) >= batch_size:
            collection.upsert(ids=batch_ids, documents=batch_docs, metadatas=batch_mds)
            batch_ids, batch_docs, batch_mds = [], [], []

    if batch_ids:
        collection.upsert(ids=batch_ids, documents=batch_docs, metadatas=batch_mds)

    print(f"[OK] {len(items)} records upserted into collection '{collection.name}'")

# %%
upsert_jsonl_direct(INPUT_PATH, sec1_col, batch_size=1000)
# Out:
# [OK] 26 records upserted into collection 'sec1'

# %% [markdown]
# ## 쿼리 테스트

# %% [markdown]
# ### 간단한 질의

# %%
import re

def extract_year(text: str) -> int | None:
    """
    질의문에서 4자리 'YYYY년' 혹은 'YYYY' 패턴을 찾아서 반환
    """
    m = re.search(r"(20\d{2}|19\d{2})년?", text)
    if m:
        return int(m.group(1))
    return None

def query_with_year_filter(collection, query_text: str, top_k: int = 3):
    # 연도 추출
    year = extract_year(query_text)

    where_clause = None
    if year:
        where_clause = {"year": year}

    # 쿼리 실행
    res = collection.query(
        query_texts=[query_text],
        n_results=top_k,
        include=["documents", "metadatas", "distances"],
        where=where_clause
    )

    # 결과 출력
    for doc, md, dist in zip(res["documents"][0], res["metadatas"][0], res["distances"][0]):
        print("="*80)
        print(f"dist={dist:.4f}")
        print("문서:", (doc[:200] + "...") if len(doc) > 200 else doc)
        print("메타:", md)

# 사용 예시
query_with_year_filter(sec1_col, "2019년 주요감사사항은?", top_k=3)
# Out:
# ================================================================================
# dist=0.6202
# 문서: 2019년 삼성전자 재무제표의 외부감사는 삼일회계법인이 수행했습니다.
# 메타: {'group_id': 'sec1-2019-root', 'parent_id': 'sec1-2019-root', 'year_anchor': '삼성전자-2019', 'kind': 'auditor', 'section': 'SEC1', 'source': '감사보고서_2019_preprocess.html#SEC1', 'year': 2019, 'company': '삼성전자', 'company_anchor': '삼성전자'}
# ================================================================================
# dist=1.2701
# 문서: 핵심감사사항 #1: 재화의 판매 관련 매출장려활동. [이유] CE(Consumer Electronics) 부문 및 IM(Information technology & Mobile communications) 부문에서 재화의 판매 시 삼성전자는 유통업자 및 통신업자 등과 매출장려활동을 수행합니다. 이러한 활동에는 할인 및 장려금 등을 제공하는 명시적이거나 암묵...
# 메타: {'reason': 'CE(Consumer Electronics) 부문 및 IM(Information technology & Mobile communications) 부문에서 재화의 판매 시 삼성전자는 유통업자 및 통신업자 등과 매출장려활동을 수행합니다. 이러한 활동에는 할인 및 장려금 등을 제공하는 명시적이거나 암묵적인 약정이 포함되어 있습니다. 삼성전자는 매출장려활동에 대한 예상지출액을 추정하여 재화의 판매에 따른 수익에서 차감합니다(주석 2.23 및 주석 3 참조).\n수익 차감 금액 및 인식 시기와 관련하여 삼성전자 경영진의 유의적인 추정 및 판단이 수반되고, 수익이 재무제표에서 차지하는 금액이 유의적이므로 재화의 판매 관련 매출장려활동의 회계처리를 핵심감사사항으로 판단하였습니다.', 'year': 2019, 'title': '재화의 판매 관련 매출장려활동', 'kam_index': 1, 'parent_id': 'sec1-2019-root', 'company_anchor': '삼성전자', 'note_refs': '2.23, 3', 'kind': 'kam', 'source': '감사보고서_2019_preprocess.html#SEC1', 'year_anchor': '삼성전자-2019', 'note_doc_ids': 'sec3-2019-note-2.23, sec3-2019-note-3', 'group_id': 'sec1-2019-root', 'company': '삼성전자', 'section': 'SEC1'}
# ================================================================================
# dist=1.3330
# 문서: 핵심감사사항 #2: 감가상각 개시시점의 적절성. [이유] 2019년 12월 31일 현재 삼성전자는 총 74090275 백만원의 유형자산을 보유하고 있으며, 해당 유형자산은 건물 및 기계장치 등을 포함하고 있습니다. 이 중 당기 중 취득으로 인한 증가금액은 18210158 백만원입니다(주석 12 참조). 삼성전자는 라인 및 설비의 사용가능시점을 판단하여 각 ...
# 메타: {'note_refs': '12, 2.9', 'year_anchor': '삼성전자-2019', 'kind': 'kam', 'company_anchor': '삼성전자', 'group_id': 'sec1-2019-root', 'year': 2019, 'note_doc_ids': 'sec3-2019-note-12, sec3-2019-note-2.9', 'section': 'SEC1', 'company': '삼성전자', 'title': '감가상각 개시시점의 적절성', 'parent_id': 'sec1-2019-root', 'source': '감사보고서_2019_preprocess.html#SEC1', 'reason': '2019년 12월 31일 현재 삼성전자는 총 74090275 백만원의 유형자산을 보유하고 있으며, 해당 유형자산은 건물 및 기계장치 등을 포함하고 있습니다. 이 중 당기 중 취득으로 인한 증가금액은 18210158 백만원입니다(주석 12 참조). 삼성전자는 라인 및 설비의 사용가능시점을 판단하여 각 자산에 대한 감가상각을 개시합니다(주석 2.9 참조).\n삼성전자의 투자규모가 크고 사용가능시점 판단에 따른 감가상각금액이 재무제표에 미치는 영향이 유의적이므로 삼일회계법인는 감가상각 개시시점의 적절성 관련 회계처리를 핵심감사사항으로 판단하였습니다.', 'kam_index': 2}

# %% [markdown]
# ### DB 구조 확인

# %%
print("== 컬렉션 목록 ==")
for c in client.list_collections():
    print("-", c.name)

# sec1 컬렉션 정보
print("\n== sec1 info ==")
info = sec1_col.get(limit=2)  # 샘플 2개만
print("id:", info["ids"])
print("문서:", info["documents"])
print("메타:", info["metadatas"])
# Out:
# == 컬렉션 목록 ==
# - sec1
#
# == sec1 info ==
# id: ['sec1-2014-auditor', 'sec1-2014-kam-none']
# 문서: ['2014년 삼성전자 재무제표의 외부감사는 삼일회계법인이 수행했습니다.', '2014년은 핵심감사사항 제도 도입 이전으로 핵심감사사항이 없습니다.']
# 메타: [{'group_id': 'sec1-2014-root', 'section': 'SEC1', 'year_anchor': '삼성전자-2014', 'company': '삼성전자', 'company_anchor': '삼성전자', 'source': '감사보고서_2014_preprocess.html#SEC1', 'kind': 'auditor', 'year': 2014, 'parent_id': 'sec1-2014-root'}, {'year_anchor': '삼성전자-2014', 'year': 2014, 'kind': 'kam_none', 'company': '삼성전자', 'parent_id': 'sec1-2014-root', 'source': '감사보고서_2014_preprocess.html#SEC1', 'section': 'SEC1', 'company_anchor': '삼성전자', 'group_id': 'sec1-2014-root'}]

# %% [markdown]
# # sec2 - 재무상태표, 손익계산서

# %%
COLL_NAME = "sec2"
sec2_col = client.get_or_create_collection(name=COLL_NAME)

# %%
upsert_jsonl_direct("../../json/손익계산서_v2.jsonl", sec2_col)

# 샘플 확인
info = sec2_col.get(limit=2)
print("샘플 id:", info["ids"])
print("샘플 문서:", info["documents"])
print("샘플 메타:", info["metadatas"])
# Out:
# [OK] 154 records upserted into collection 'sec2'
# 샘플 id: ['sec2-2014-is-매출액-매출액', 'sec2-2014-is-매출원가-매출원가']
# 샘플 문서: ['2014년 삼성전자의 매출액은(는) 137,825,547 백만원입니다(전기 158,372,089 백만원).', '2014년 삼성전자의 매출원가은(는) 99,188,713 백만원입니다(전기 110,731,528 백만원).']
# 샘플 메타: [{'statement_anchor': '삼성전자-2014-is', 'statement_code': 'is', 'group_id': 'sec2-2014-is-root', 'line_item': '매출액', 'section': 'SEC2', 'year': 2014, 'unit': 'KRW_million', 'note_refs': '', 'path_labels': '매출액', 'note_doc_ids': '', 'year_anchor': '삼성전자-2014', 'statement': '손익계산서', 'path_codes': '매출액', 'path_ord': '1, 1', 'company': '삼성전자', 'parent_id': 'sec2-2014-is-node-매출액'}, {'section': 'SEC2', 'statement_code': 'is', 'note_doc_ids': 'sec3-2014-note-25', 'line_item': '매출원가', 'year_anchor': '삼성전자-2014', 'note_refs': '25', 'statement_anchor': '삼성전자-2014-is', 'group_id': 'sec2-2014-is-root', 'path_codes': '매출원가', 'path_ord': '1, 2', 'year': 2014, 'company': '삼성전자', 'unit': 'KRW_million', 'statement': '손익계산서', 'path_labels': '매출원가', 'parent_id': 'sec2-2014-is-node-매출원가'}]

# %%
upsert_jsonl_direct("../../json/재무상태표.jsonl", sec2_col)
# Out:
# [OK] 501 records upserted into collection 'sec2'

# %%
upsert_jsonl_direct("../../json/현금흐름표.jsonl", sec2_col)
upsert_jsonl_direct("../../json/자본변동표_dedup.jsonl", sec2_col)
upsert_jsonl_direct("../../json/포괄손익계산서.jsonl", sec2_col)
# Out:
# [OK] 346 records upserted into collection 'sec2'
# [OK] 265 records upserted into collection 'sec2'
# [OK] 33 records upserted into collection 'sec2'

# %%
query_text = "2019년 매출은 얼마야?"
res = query_with_year_filter(sec2_col, query_text, top_k=3)
# Out:
# ================================================================================
# dist=0.5553
# 문서: 2019년의 삼성전자 부채에서 유동부채 중 하나인 단기차입금은(는) 10,228,216 백만원입니다.
# 메타: {'statement': '재무상태표', 'statement_code': 'bs', 'year': 2019, 'path_ord': '2, 1, 2', 'group_id': 'sec2-2019-bs-root', 'section': 'SEC2', 'path_codes': '부채, 유동부채', 'path_labels': '부채, 유동부채', 'year_anchor': '삼성전자-2019', 'company': '삼성전자', 'parent_id': 'sec2-2019-bs-node-부채-유동부채', 'statement_anchor': '삼성전자-2019-bs', 'unit': 'KRW_million', 'note_doc_ids': 'sec3-2019-note-6, sec3-2019-note-7, sec3-2019-note-14, sec3-2019-note-30', 'line_index': 2, 'note_refs': '6, 7, 14, 30', 'line_item': '단기차입금'}
# ================================================================================
# dist=0.5836
# 문서: 2019년의 삼성전자 매출총이익 중 하나인 판매비와관리비은(는) 27,039,348 백만원입니다.
# 메타: {'path_codes': '매출총이익', 'group_id': 'sec2-2019-is-root', 'statement_anchor': '삼성전자-2019-is', 'note_refs': '23, 24', 'unit': 'KRW_million', 'statement': '손익계산서', 'year': 2019, 'company': '삼성전자', 'path_labels': '매출총이익', 'section': 'SEC2', 'line_item': '판매비와관리비', 'note_doc_ids': 'sec3-2019-note-23, sec3-2019-note-24', 'year_anchor': '삼성전자-2019', 'statement_code': 'is', 'path_ord': '1, 3, 1', 'parent_id': 'sec2-2019-is-node-매출총이익'}
# ================================================================================
# dist=0.5929
# 문서: 2019년의 삼성전자 부채에서 유동부채 중 하나인 미지급비용은(는) 5,359,291 백만원입니다.
# 메타: {'note_doc_ids': 'sec3-2019-note-6, sec3-2019-note-19', 'statement': '재무상태표', 'company': '삼성전자', 'line_index': 6, 'path_codes': '부채, 유동부채', 'group_id': 'sec2-2019-bs-root', 'parent_id': 'sec2-2019-bs-node-부채-유동부채', 'note_refs': '6, 19', 'year': 2019, 'statement_anchor': '삼성전자-2019-bs', 'statement_code': 'bs', 'path_labels': '부채, 유동부채', 'path_ord': '2, 1, 6', 'year_anchor': '삼성전자-2019', 'unit': 'KRW_million', 'line_item': '미지급비용', 'section': 'SEC2'}

# %% [markdown]
# # QA 성능평가

# %%
import re, textwrap
from typing import Dict, Any, List

COL_NAMES = ["sec1", "sec2"]
collections = {name: client.get_collection(name=name) for name in COL_NAMES}

# %%
import json
import textwrap

# --------------------------------------------------------
# QA 파일 로더
def read_qa(path: str):
    import io
    def _strip_bom(s: str) -> str:
        return s[1:] if s and s[0] == "\ufeff" else s
    with open(path, "r", encoding="utf-8") as f:
        raw = _strip_bom(f.read()).strip()
    if raw.startswith("["):
        return json.loads(raw)
    items = []
    for line in io.StringIO(raw):
        line = line.strip()
        if not line or line.startswith("//") or line.startswith("#"):
            continue
        if line.endswith(","):
            line = line[:-1]
        items.append(json.loads(line))
    return items


# --------------------------------------------------------
# Reciprocal Rank 계산 (여러 정답 평균)
def reciprocal_rank_avg(ranked_ids, gold_ids):
    ranks = []
    for g in gold_ids:
        if g in ranked_ids:
            r = ranked_ids.index(g) + 1   # 1-based rank
            ranks.append(1.0 / r)
    if not ranks:
        return 0.0
    return sum(ranks) / len(ranks)

# 전체 MRR_avg 평가 (scores도 반환)
def eval_mrr_avg(qa_path: str, top_k: int = 10, max_samples: int = None):
    qa_items = read_qa(qa_path)
    if max_samples:
        qa_items = qa_items[:max_samples]

    scores = []
    for idx, item in enumerate(qa_items, 1):
        qid   = item.get("id")
        qtext = item.get("question", "")
        golds = item.get("answers", [])

        merged = []
        for cname in ["sec1", "sec2"]:
            try:
                res = collections[cname].query(
                    query_texts=[qtext],
                    n_results=top_k,
                    include=["documents", "metadatas", "distances"],  # ✅ ids는 자동 반환
                )
                for doc_id, dist in zip(res["ids"][0], res["distances"][0]):
                    merged.append((dist, doc_id))
            except Exception as e:
                print(f"[{qid}] query error on {cname}: {e}")

        # 거리 기준 정렬 후 상위 top_k
        merged.sort(key=lambda x: x[0])
        ranked_ids = [doc_id for _, doc_id in merged[:top_k]]

        rr_avg = reciprocal_rank_avg(ranked_ids, golds)
        scores.append(rr_avg)

        print(f"[{idx}] {qid} | RR_avg={rr_avg:.4f} | Q='{qtext}'")
        print(f"   Gold: {golds}")
        print(f"   Top-{top_k}: {ranked_ids}")
        print()

    mrr_avg = sum(scores) / len(scores) if scores else 0.0
    print("="*80)
    print(f"MRR_avg (over {len(scores)} questions, top-{top_k}) = {mrr_avg:.4f}")

    # ✅ 이제 (평균, 점수 리스트) 둘 다 반환
    return mrr_avg, scores

# --------------------------------------------------------
# 실행 예시
QA_PATH = "../../qa_dataset_50_revised.jsonl"
mrr_value, scores = eval_mrr_avg(QA_PATH, top_k=10, max_samples=50)
# Out:
# [1] Q001 | RR_avg=0.0000 | Q='2019년 감사보고서를 담당한 회계 감사 기관은 어디인가?'
#    Gold: ['sec1-2019-auditor']
#    Top-10: ['sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-총계', 'sec2-2019-se-총포괄손익-1-당기순이익-이익잉여금-1c2e8260', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce', 'sec2-2019-se-총포괄손익-1-당기순이익-총계-200000bb']
#
# [2] Q002 | RR_avg=0.0000 | Q='2020년 감사를 담당한 곳은?'
#    Gold: ['sec1-2020-auditor']
#    Top-10: ['sec2-2020-se-자본에직접인식된주주와의거래-1-배당-총계-46f2b324', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-총계', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-d3396e7d', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2020-cf-현금흐름-영업활동현금흐름-업활동현금흐름', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-bs-root-부채와자본총계', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2020-cf-현금흐름-투자활동현금흐름-6-종속기업-관계기업및공동기업투자의처분']
#
# [3] Q003 | RR_avg=0.0000 | Q='2023년 핵심감사사항은?'
#    Gold: ['sec1-2023-kam-1']
#    Top-10: ['sec2-2023-is-당기순이익-당기순이익', 'sec2-2023-ci-당기순이익', 'sec2-2023-bs-자본-이익잉여금-이익잉여금', 'sec2-2023-bs-자본-자본금-자본금', 'sec2-2023-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2023-is-매출액-매출액', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-bs-root-부채와자본총계', 'sec2-2022-cf-현금흐름-재무활동현금흐름-무활동현금흐름']
#
# [4] Q004 | RR_avg=0.0000 | Q='2018년 재화의 판매 관련 매출장려활동이 핵심감사사항으로 결정된 이유는?'
#    Gold: ['sec1-2018-kam-1']
#    Top-10: ['sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-기타자본항목', 'sec2-2018-cf-현금흐름-투자활동현금흐름-4-장기매도가능금융자산의처분', 'sec2-2018-se-총포괄손익-3-순확정급여자산재측정요소-총계-c1b6caec', 'sec2-2018-se-총포괄손익-3-순확정급여자산재측정요소-기타자본항목-59b45cae', 'sec2-2019-cf-현금흐름-투자활동현금흐름-12-무형자산의처분', 'sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2019-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-총계', 'sec2-2020-se-총포괄손익-3-순확정급여부채재측정요소-총계', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-기타자본항목-b6143e85']
#
# [5] Q005 | RR_avg=0.0000 | Q='2019년 감가상각 개시 시점의 적절성이 왜 핵심감사사항?'
#    Gold: ['sec1-2019-kam-1']
#    Top-10: ['sec2-2018-cf-현금흐름-투자활동현금흐름-4-장기매도가능금융자산의처분', 'sec2-2018-se-총포괄손익-3-순확정급여자산재측정요소-총계-c1b6caec', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계-4da696b1', 'sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목-15388e4d', 'sec2-2019-cf-현금흐름-투자활동현금흐름-12-무형자산의처분', 'sec2-2020-se-총포괄손익-3-순확정급여부채재측정요소-총계']
#
# [6] Q006 | RR_avg=0.0000 | Q='2016년 투자 활동에 따른 현금 흐름은 얼마인가?'
#    Gold: ['sec2-2016-cf-현금흐름-투자활동현금흐름-자활동현금흐름']
#    Top-10: ['sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2016-cf-현금흐름-재무활동현금흐름-5-배당금의지급', 'sec2-2016-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순증가', 'sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2016-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2016-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2017-cf-현금흐름-투자활동현금흐름-6-장기매도가능금융자산의취득', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2018-cf-현금흐름-투자활동현금흐름-5-장기매도가능금융자산의취득', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가']
#
# [7] Q007 | RR_avg=0.0000 | Q='2014년과 2015년 단기 매도 가능한 금융자산은 얼마인가?'
#    Gold: ['sec2-2014-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2015-bs-자산-유동자산-3-단기매도가능금융자산']
#    Top-10: ['sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2015-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2015-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2015-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2016-se-총포괄손익-1-당기순이익-총계', 'sec2-2016-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2014-se-총포괄손익-1-당기순이익-이익잉여금-fed1d473', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593']
#
# [8] Q008 | RR_avg=0.0000 | Q='2016년 사채은 얼마인가?'
#    Gold: ['sec2-2016-bs-부채-비유동부채-1-사채']
#    Top-10: ['sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2016-bs-부채-유동부채-2-단기차입금', 'sec2-2016-is-매출총이익-판매비와관리비', 'sec2-2016-cf-현금흐름-외화환산으로인한현금의변동-화환산으로인한현금의변동', 'sec2-2017-bs-부채-유동부채-2-단기차입금', 'sec2-2017-bs-부채-비유동부채-1-사채', 'sec2-2016-cf-현금흐름-재무활동현금흐름-무활동현금흐름', 'sec2-2016-is-매출액-매출액', 'sec2-2017-se-자본에직접인식된주주와의거래-1-배당-총계', 'sec2-2018-bs-부채-유동부채-2-단기차입금']
#
# [9] Q009 | RR_avg=0.0000 | Q='2016년과 2024년 법인세 비용 차감 전 순이익은 얼마인가?'
#    Gold: ['sec2-2016-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2024-is-법인세비용차감전순이익-법인세비용차감전순이익']
#    Top-10: ['sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2017-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2019-se-root-수정후기초자본-총계', 'sec2-2019-se-root-수정후기초자본-이익잉여금', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2016-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2017-se-총포괄손익-1-당기순이익-총계', 'sec2-2016-cf-현금흐름-재무활동현금흐름-5-배당금의지급']
#
# [10] Q010 | RR_avg=0.0000 | Q='2014년과 2015년 미수금은 각각 얼마인가?'
#    Gold: ['sec2-2014-bs-자산-유동자산-5-미수금', 'sec2-2015-bs-자산-유동자산-5-미수금']
#    Top-10: ['sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2016-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2015-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2016-se-총포괄손익-1-당기순이익-총계', 'sec2-2014-se-총포괄손익-1-당기순이익-이익잉여금-fed1d473', 'sec2-2015-se-총포괄손익-1-당기순이익-이익잉여금-ee10f5b6', 'sec2-2015-is-매출총이익-판매비와관리비']
#
# [11] Q011 | RR_avg=0.0000 | Q='2019년부터 2024년까지의 기타수익은 얼마인가?'
#    Gold: ['sec2-2019-is-영업이익-기타수익', 'sec2-2020-is-영업이익-기타수익', 'sec2-2021-is-영업이익-기타수익', 'sec2-2022-is-영업이익-기타수익', 'sec2-2023-is-영업이익-손실-기타수익', 'sec2-2024-is-영업이익-손실-기타수익']
#    Top-10: ['sec2-2019-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2019-se-root-수정후기초자본-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2019-se-root-수정후기초자본-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-총계', 'sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2018-se-자본에직접인식된주주와의거래-회계정책변경누적효과-기타자본항목']
#
# [12] Q012 | RR_avg=0.0000 | Q='2024년 말 이익잉여금은 얼마인가?'
#    Gold: ['sec2-2024-bs-자본-이익잉여금-이익잉여금']
#    Top-10: ['sec2-2022-cf-현금흐름-재무활동현금흐름-무활동현금흐름', 'sec2-2024-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2024-se-총포괄손익-1-당기순이익-총계-3d0daeb3', 'sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금-80261615', 'sec2-2024-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2024-cf-현금흐름-투자활동현금흐름-10-무형자산의취득', 'sec2-2023-is-매출액-매출액', 'sec2-2022-se-총포괄손익-1-당기순이익-총계-53b7d068']
#
# [13] Q013 | RR_avg=0.0000 | Q='2014년부터 2019년까지 단기 금융 상품의 순감소 또는 증가는 얼마인가?'
#    Gold: ['sec2-2014-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2017-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2019-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가']
#    Top-10: ['sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계']
#
# [14] Q014 | RR_avg=0.0000 | Q='최근 6년 동안 희석 주당 이익의 값은?'
#    Gold: ['sec2-2024-is-주당이익-희석주당이익', 'sec2-2023-is-주당이익-희석주당이익', 'sec2-2022-is-주당이익-희석주당이익', 'sec2-2021-is-주당이익-희석주당이익', 'sec2-2020-is-주당이익-희석주당이익', 'sec2-2019-is-주당이익-희석주당이익']
#    Top-10: ['sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금-de53424b', 'sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목-15388e4d', 'sec2-2014-se-총포괄손익-1-당기순이익-총계', 'sec2-2015-se-총포괄손익-1-당기순이익-총계-d16f743f', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2017-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-fddb7372', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계']
#
# [15] Q015 | RR_avg=0.0000 | Q='2024년 예수금액은?'
#    Gold: ['sec2-2024-bs-부채-유동부채-5-예수금']
#    Top-10: ['sec2-2024-cf-현금흐름-기초의현금및현금성자산-초의현금및현금성자산', 'sec2-2023-cf-현금흐름-기말의현금및현금성자산-말의현금및현금성자산', 'sec2-2024-is-매출액-매출액', 'sec2-2023-is-당기순이익-당기순이익', 'sec2-2023-ci-당기순이익', 'sec2-2024-cf-현금흐름-기말의현금및현금성자산-말의현금및현금성자산', 'sec2-2024-bs-자본-자본총계', 'sec2-2023-bs-root-부채와자본총계', 'sec2-2022-bs-자본-자본총계', 'sec2-2023-bs-자본-자본총계']
#
# [16] Q016 | RR_avg=0.5000 | Q='2017년 사채의 상환은 얼마인가?'
#    Gold: ['sec2-2017-cf-현금흐름-재무활동현금흐름-3-사채의상환']
#    Top-10: ['sec2-2017-cf-현금흐름-투자활동현금흐름-6-장기매도가능금융자산의취득', 'sec2-2017-cf-현금흐름-재무활동현금흐름-3-사채의상환', 'sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2017-cf-현금흐름-투자활동현금흐름-12-무형자산의취득', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2017-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2021-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2017-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2017-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분']
#
# [17] Q017 | RR_avg=0.0000 | Q='2016년 무형 자산의 구매는 얼마인가?'
#    Gold: ['sec2-2016-cf-현금흐름-투자활동현금흐름-12-무형자산의취득']
#    Top-10: ['sec2-2017-se-총포괄손익-1-당기순이익-총계', 'sec2-2016-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순증가', 'sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2017-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2017-se-총포괄손익-2-매도가능금융자산평가-매각예정분류기타자본항목', 'sec2-2016-cf-현금흐름-재무활동현금흐름-5-배당금의지급', 'sec2-2016-is-매출총이익-판매비와관리비', 'sec2-2016-se-총포괄손익-2-매도가능금융자산평가-매각예정분류기타자본항목-eb55eb04', 'sec2-2017-se-총포괄손익-2-매도가능금융자산평가-총계', 'sec2-2016-se-총포괄손익-1-당기순이익-총계-4cf49de0']
#
# [18] Q018 | RR_avg=0.0000 | Q='2020년 조정 금액은?'
#    Gold: ['sec2-2020-cf-현금흐름-영업활동현금흐름-조정']
#    Top-10: ['sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2021-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2020-bs-root-부채와자본총계', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-d3396e7d', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2020-cf-현금흐름-투자활동현금흐름-9-유형자산의취득']
#
# [19] Q019 | RR_avg=0.0000 | Q='2014년부터 2024년까지 선수금은 얼마인가?'
#    Gold: ['sec2-2014-bs-부채-유동부채-4-선수금', 'sec2-2015-bs-부채-유동부채-4-선수금', 'sec2-2016-bs-부채-유동부채-4-선수금', 'sec2-2017-bs-부채-유동부채-4-선수금', 'sec2-2018-bs-부채-유동부채-4-선수금', 'sec2-2019-bs-부채-유동부채-4-선수금', 'sec2-2020-bs-부채-유동부채-4-선수금', 'sec2-2021-bs-부채-유동부채-4-선수금', 'sec2-2022-bs-부채-유동부채-4-선수금', 'sec2-2023-bs-부채-유동부채-4-선수금', 'sec2-2024-bs-부채-유동부채-4-선수금']
#    Top-10: ['sec2-2015-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-cf-현금흐름-투자활동현금흐름-자활동현금흐름', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2015-se-총포괄손익-1-당기순이익-총계', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분']
#
# [20] Q020 | RR_avg=0.0000 | Q='2020년 유동성 장기 채무는 얼마인가?'
#    Gold: ['sec2-2020-bs-부채-유동부채-8-유동성장기부채']
#    Top-10: ['sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2021-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-is-매출총이익-판매비와관리비', 'sec2-2020-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2020-ci-총포괄손익', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2020-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가']
#
# [21] Q021 | RR_avg=0.1429 | Q='2022년 매입 채무는 얼마인가?'
#    Gold: ['sec2-2022-bs-부채-유동부채-1-매입채무']
#    Top-10: ['sec2-2022-is-매출원가-매출원가', 'sec2-2022-bs-자산-유동자산-4-미수금', 'sec2-2022-bs-부채-유동부채-3-미지급금', 'sec2-2023-bs-부채-유동부채-3-미지급금', 'sec2-2022-is-매출총이익-판매비와관리비', 'sec2-2022-is-매출액-매출액', 'sec2-2022-bs-부채-유동부채-1-매입채무', 'sec2-2023-is-매출액-매출액', 'sec2-2022-is-영업이익-기타수익', 'sec2-2022-bs-부채-유동부채-2-단기차입금']
#
# [22] Q022 | RR_avg=0.0000 | Q='2015년부터 2017년까지 단기 차입금 증가액은?'
#    Gold: ['sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2016-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2017-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가']
#    Top-10: ['sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec1-2015-kam-none', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계']
#
# [23] Q023 | RR_avg=0.0000 | Q='2015년 보통주 자본금은 얼마인가?'
#    Gold: ['sec2-2015-bs-자본-자본금-2-보통주자본금']
#    Top-10: ['sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2015-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2015-bs-자산-비유동자산-비유동자산', 'sec2-2015-cf-현금흐름-투자활동현금흐름-자활동현금흐름']
#
# [24] Q024 | RR_avg=0.0000 | Q='2016년과 2021년 재고자산은 각각 얼마인가?'
#    Gold: ['sec2-2016-bs-자산-유동자산-8-재고자산', 'sec2-2021-bs-자산-유동자산-6-재고자산']
#    Top-10: ['sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2019-se-root-수정후기초자본-총계', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2021-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce', 'sec2-2019-se-총포괄손익-1-당기순이익-총계', 'sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목-15388e4d']
#
# [25] Q025 | RR_avg=0.0000 | Q='최근 5년 동안 장기 금융 상품의 취득의 값은?'
#    Gold: ['sec2-2024-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득', 'sec2-2023-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2022-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2021-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2020-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득']
#    Top-10: ['sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-총계-32c787e4', 'sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-기타자본항목-5e429190', 'sec2-2016-se-자본에직접인식된주주와의거래-2-자기주식의취득-기타자본항목', 'sec2-2016-se-자본에직접인식된주주와의거래-2-자기주식의취득-총계', 'sec2-2015-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득', 'sec2-2015-cf-현금흐름-재무활동현금흐름-2-자기주식의취득', 'sec2-2018-cf-현금흐름-투자활동현금흐름-5-장기매도가능금융자산의취득', 'sec2-2015-cf-현금흐름-재무활동현금흐름-4-사채의상환', 'sec2-2019-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2019-cf-현금흐름-투자활동현금흐름-7-당기손익공정가치금융자산의취득']
#
# [26] Q026 | RR_avg=0.0000 | Q='최근 10년 동안 유동 부채의 값은?'
#    Gold: ['sec2-2014-bs-부채-유동부채-유동부채', 'sec2-2015-bs-부채-유동부채-유동부채', 'sec2-2016-bs-부채-유동부채-유동부채', 'sec2-2017-bs-부채-유동부채-유동부채', 'sec2-2018-bs-부채-유동부채-유동부채', 'sec2-2019-bs-부채-유동부채-유동부채', 'sec2-2020-bs-부채-유동부채-유동부채', 'sec2-2021-bs-부채-유동부채-유동부채', 'sec2-2022-bs-부채-유동부채-유동부채', 'sec2-2023-bs-부채-유동부채-유동부채']
#    Top-10: ['sec2-2019-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-3040b294', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-d3396e7d', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-총계-46f2b324', 'sec2-2019-se-자본에직접인식된주주와의거래-1-배당-총계-7781d524', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-총계', 'sec2-2021-se-자본에직접인식된주주와의거래-1-배당-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-f897e86d', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금']
#
# [27] Q027 | RR_avg=0.0000 | Q='2023년과 2024년 단기 금융 상품은 각각 얼마인가?'
#    Gold: ['sec2-2023-bs-자산-유동자산-2-단기금융상품', 'sec2-2024-bs-자산-유동자산-2-단기금융상품']
#    Top-10: ['sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2023-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2023-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2023-se-총포괄손익-1-당기순이익-이익잉여금-eb01ba6e', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2023-bs-자본-이익잉여금-이익잉여금', 'sec2-2023-is-당기순이익-당기순이익', 'sec2-2023-ci-당기순이익']
#
# [28] Q028 | RR_avg=0.0000 | Q='최근 6년 동안 무형 자산의 값은?'
#    Gold: ['sec2-2024-bs-자산-비유동자산-4-무형자산', 'sec2-2023-bs-자산-비유동자산-4-무형자산', 'sec2-2022-bs-자산-비유동자산-6-무형자산', 'sec2-2021-bs-자산-비유동자산-5-무형자산', 'sec2-2020-bs-자산-비유동자산-5-무형자산', 'sec2-2020-bs-자산-비유동자산-5-무형자산']
#    Top-10: ['sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목-15388e4d', 'sec2-2018-se-자본에직접인식된주주와의거래-회계정책변경누적효과-기타자본항목', 'sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금-de53424b', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2019-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-3040b294', 'sec2-2018-se-자본에직접인식된주주와의거래-회계정책변경누적효과-이익잉여금', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계-4da696b1']
#
# [29] Q029 | RR_avg=1.0000 | Q='2019년 사업 결합으로인한 현금유출액은 얼마인가?'
#    Gold: ['sec2-2019-cf-현금흐름-투자활동현금흐름-14-사업결합으로인한현금유출액']
#    Top-10: ['sec2-2019-cf-현금흐름-투자활동현금흐름-14-사업결합으로인한현금유출액', 'sec2-2018-cf-현금흐름-영업활동현금흐름-4-배당금수입', 'sec2-2021-cf-현금흐름-영업활동현금흐름-4-배당금수입', 'sec2-2018-cf-현금흐름-투자활동현금흐름-16-현금의기타유출입', 'sec2-2020-cf-현금흐름-투자활동현금흐름-12-사업결합으로인한현금유출액', 'sec2-2019-cf-현금흐름-영업활동현금흐름-3-이자의지급', 'sec2-2018-cf-현금흐름-투자활동현금흐름-4-장기매도가능금융자산의처분', 'sec2-2019-cf-현금흐름-투자활동현금흐름-12-무형자산의처분', 'sec2-2018-cf-현금흐름-투자활동현금흐름-12-유형자산의처분', 'sec2-2019-cf-현금흐름-영업활동현금흐름-4-배당금수입']
#
# [30] Q030 | RR_avg=1.0000 | Q='2016년 단기 금융 상품의 순증가은 얼마인가?'
#    Gold: ['sec2-2016-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순증가']
#    Top-10: ['sec2-2016-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순증가', 'sec2-2017-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2016-se-총포괄손익-3-순확정급여자산재측정요소-총계-4f23cee5', 'sec2-2016-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2018-se-총포괄손익-3-순확정급여자산재측정요소-총계-c1b6caec', 'sec2-2016-cf-현금흐름-재무활동현금흐름-5-배당금의지급', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2016-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계']
#
# [31] Q031 | RR_avg=0.0000 | Q='2020년부터 2022년까지 당기 법인세 채무는 얼마인가?'
#    Gold: ['sec2-2020-bs-부채-유동부채-7-당기법인세부채', 'sec2-2021-bs-부채-유동부채-7-당기법인세부채', 'sec2-2022-bs-부채-유동부채-7-당기법인세부채']
#    Top-10: ['sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2020-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2021-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce', 'sec2-2020-cf-현금흐름-투자활동현금흐름-6-종속기업-관계기업및공동기업투자의처분', 'sec2-2020-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-is-매출총이익-판매비와관리비', 'sec2-2020-cf-현금흐름-투자활동현금흐름-10-무형자산의처분']
#
# [32] Q032 | RR_avg=0.0000 | Q='2019년부터 2023년까지 장기 차입금은 얼마인가?'
#    Gold: ['sec2-2019-bs-부채-비유동부채-2-장기차입금', 'sec2-2020-bs-부채-비유동부채-2-장기차입금', 'sec2-2021-bs-부채-비유동부채-2-장기차입금', 'sec2-2022-bs-부채-비유동부채-2-장기차입금', 'sec2-2023-bs-부채-비유동부채-2-장기차입금']
#    Top-10: ['sec2-2019-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2019-se-root-수정후기초자본-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-se-총포괄손익-1-당기순이익-총계', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2019-se-root-수정후기초자본-이익잉여금']
#
# [33] Q033 | RR_avg=0.0000 | Q='2016년 기타 비유동 자산은 얼마인가?'
#    Gold: ['sec2-2016-bs-자산-비유동자산-8-기타비유동자산']
#    Top-10: ['sec2-2019-se-root-수정후기초자본-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-총계', 'sec2-2017-se-총포괄손익-1-당기순이익-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2016-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-기타자본항목', 'sec2-2019-se-총포괄손익-1-당기순이익-총계', 'sec2-2017-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2016-se-총포괄손익-1-당기순이익-총계-4cf49de0']
#
# [34] Q034 | RR_avg=0.0000 | Q='최근 5년 동안 현금 및 현금성 자산의 변화량은?'
#    Gold: ['sec2-2024-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2023-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2022-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2021-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2020-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소']
#    Top-10: ['sec2-2015-cf-현금흐름-투자활동현금흐름-3-단기매도가능금융자산의취득', 'sec2-2015-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득', 'sec2-2015-cf-현금흐름-재무활동현금흐름-2-자기주식의취득', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-총계-32c787e4', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-기타자본항목-5e429190', 'sec2-2019-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2019-cf-현금흐름-투자활동현금흐름-7-당기손익공정가치금융자산의취득', 'sec2-2018-cf-현금흐름-투자활동현금흐름-5-장기매도가능금융자산의취득']
#
# [35] Q035 | RR_avg=0.0000 | Q='2022년과 2023년 기타 포괄손익공정가치 금융자산의 취득은 각각 얼마인가?'
#    Gold: ['sec2-2022-cf-현금흐름-투자활동현금흐름-3-기타포괄손익공정가치금융자산의취득', 'sec2-2023-cf-현금흐름-투자활동현금흐름-3-기타포괄손익공정가치금융자산의취득']
#    Top-10: ['sec2-2023-cf-현금흐름-투자활동현금흐름-4-당기손익공정가치금융자산의처분', 'sec2-2023-bs-자본-이익잉여금-이익잉여금', 'sec2-2024-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-총계', 'sec2-2022-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2023-cf-현금흐름-투자활동현금흐름-7-유형자산의처분', 'sec2-2023-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-총계-e9d422c5', 'sec2-2022-cf-현금흐름-투자활동현금흐름-2-기타포괄손익공정가치금융자산의처분', 'sec2-2023-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2022-cf-현금흐름-투자활동현금흐름-9-무형자산의처분', 'sec2-2023-cf-현금흐름-투자활동현금흐름-2-기타포괄손익공정가치금융자산의처분']
#
# [36] Q036 | RR_avg=0.0000 | Q='2015년과 2016년 장기 매도 가능한 금융 자산은 각각 얼마인가?'
#    Gold: ['sec2-2015-bs-자산-비유동자산-1-장기매도가능금융자산', 'sec2-2016-bs-자산-비유동자산-1-장기매도가능금융자산']
#    Top-10: ['sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2016-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2015-se-총포괄손익-3-순확정급여자산재측정요소-총계-8797d8b1', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2017-se-총포괄손익-1-당기순이익-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d']
#
# [37] Q037 | RR_avg=0.0000 | Q='2014년 단기 매도 가능한 금융자산의순감소은 얼마인가?'
#    Gold: ['sec2-2014-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의순감소']
#    Top-10: ['sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2014-se-총포괄손익-1-당기순이익-이익잉여금-fed1d473', 'sec2-2015-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-기타자본항목', 'sec2-2015-se-총포괄손익-1-당기순이익-총계', 'sec2-2015-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2014-se-총포괄손익-1-당기순이익-총계-b932deed', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분']
#
# [38] Q038 | RR_avg=0.0000 | Q='최근 6년 동안 발행 주식 총액은?'
#    Gold: ['sec2-2024-bs-자본-자본금-자본금', 'sec2-2023-bs-자본-자본금-자본금', 'sec2-2022-bs-자본-자본금-자본금', 'sec2-2021-bs-자본-자본금-자본금', 'sec2-2020-bs-자본-자본금-자본금', 'sec2-2019-bs-자본-자본금-자본금']
#    Top-10: ['sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금-de53424b', 'sec2-2018-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목-15388e4d', 'sec2-2019-cf-현금흐름-투자활동현금흐름-5-기타포괄손익공정가치금융자산의취득', 'sec2-2014-se-총포괄손익-1-당기순이익-총계', 'sec2-2018-se-총포괄손익-1-당기순이익-총계-8bdcc1b9', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2019-cf-현금흐름-투자활동현금흐름-15-기타투자활동으로인한현금유출입액', 'sec2-2017-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-fddb7372', 'sec2-2019-se-총포괄손익-1-당기순이익-총계']
#
# [39] Q039 | RR_avg=0.0000 | Q='2021년과 2022년 추가 포괄 이익은?'
#    Gold: ['sec2-2021-ci-기타포괄손익', 'sec2-2022-ci-기타포괄손익']
#    Top-10: ['sec2-2023-se-총포괄손익-1-당기순이익-총계', 'sec2-2022-se-총포괄손익-1-당기순이익-총계-53b7d068', 'sec2-2023-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2022-se-총포괄손익-1-당기순이익-이익잉여금-09ef035f', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2022-ci-총포괄손익', 'sec2-2023-se-총포괄손익-1-당기순이익-이익잉여금-eb01ba6e', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2022-is-매출총이익-판매비와관리비']
#
# [40] Q040 | RR_avg=0.0000 | Q='2016년과 2023년 매출 총 이익은'
#    Gold: ['sec2-2016-is-매출총이익-매출총이익', 'sec2-2023-is-매출총이익-매출총이익']
#    Top-10: ['sec2-2023-bs-자본-이익잉여금-이익잉여금', 'sec2-2023-cf-현금흐름-투자활동현금흐름-7-유형자산의처분', 'sec2-2020-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2023-bs-부채-유동부채-7-당기법인세부채', 'sec2-2023-cf-현금흐름-투자활동현금흐름-2-기타포괄손익공정가치금융자산의처분', 'sec2-2023-cf-현금흐름-투자활동현금흐름-4-당기손익공정가치금융자산의처분', 'sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2023-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2020-bs-자본-이익잉여금-이익잉여금', 'sec2-2023-cf-현금흐름-영업활동현금흐름-당기순이익']
#
# [41] Q041 | RR_avg=0.0000 | Q='2014년과 2015년 매각예정분류부채는 얼마인가?'
#    Gold: ['sec2-2014-bs-부채-유동부채-11-매각예정분류부채', 'sec2-2015-bs-부채-유동부채-11-매각예정분류부채']
#    Top-10: ['sec2-2015-bs-자산-비유동자산-4-무형자산', 'sec2-2015-is-매출총이익-판매비와관리비', 'sec2-2015-is-매출액-매출액', 'sec2-2015-cf-현금흐름-외화환산으로인한현금의변동-화환산으로인한현금의변동', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2015-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2015-bs-자산-유동자산-5-미수금', 'sec2-2015-is-영업이익-금융수익', 'sec2-2015-cf-현금흐름-투자활동현금흐름-자활동현금흐름', 'sec2-2015-bs-자본-자본금-1-우선주자본금']
#
# [42] Q042 | RR_avg=0.0000 | Q='2018년과 2019년 당기 손익 공정가치 금융 자산의취득은?'
#    Gold: ['sec2-2018-cf-현금흐름-투자활동현금흐름-9-당기손익공정가치금융자산의취득', 'sec2-2019-cf-현금흐름-투자활동현금흐름-7-당기손익공정가치금융자산의취득']
#    Top-10: ['sec2-2019-se-root-수정후기초자본-주식발행초과금', 'sec2-2019-se-root-수정후기초자본-총계', 'sec2-2018-cf-현금흐름-투자활동현금흐름-4-장기매도가능금융자산의처분', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-주식발행초과금', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계', 'sec2-2018-se-자본에직접인식된주주와의거래-수정후기초자본-이익잉여금', 'sec2-2019-se-root-수정후기초자본-이익잉여금', 'sec2-2018-se-총포괄손익-3-순확정급여자산재측정요소-총계-c1b6caec', 'sec2-2019-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2020-se-총포괄손익-3-순확정급여부채재측정요소-총계']
#
# [43] Q043 | RR_avg=0.0000 | Q='최근 10년 동안 부채 총합은?'
#    Gold: ['sec2-2014-bs-부채-부채총계', 'sec2-2015-bs-부채-부채총계', 'sec2-2016-bs-부채-부채총계', 'sec2-2017-bs-부채-부채총계', 'sec2-2018-bs-부채-부채총계', 'sec2-2020-bs-부채-부채총계', 'sec2-2021-bs-부채-부채총계', 'sec2-2022-bs-부채-부채총계', 'sec2-2023-bs-부채-부채총계', 'sec2-2024-bs-부채-부채총계']
#    Top-10: ['sec2-2019-cf-현금흐름-재무활동현금흐름-4-배당금의지급', 'sec2-2019-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2019-cf-현금흐름-투자활동현금흐름-7-당기손익공정가치금융자산의취득', 'sec2-2019-cf-현금흐름-재무활동현금흐름-2-자기주식의취득', 'sec2-2019-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-3040b294', 'sec2-2018-cf-현금흐름-영업활동현금흐름-2-이자의수취', 'sec2-2015-cf-현금흐름-영업활동현금흐름-1-영업에서창출된현금흐름', 'sec2-2018-cf-현금흐름-투자활동현금흐름-5-장기매도가능금융자산의취득', 'sec2-2015-bs-자산-비유동자산-비유동자산', 'sec2-2020-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-d3396e7d']
#
# [44] Q044 | RR_avg=0.0000 | Q='2016년과 2020년 현금 자산은 얼마인가?'
#    Gold: ['sec2-2016-bs-자산-유동자산-1-현금및현금성자산', 'sec2-2020-bs-자산-유동자산-1-현금및현금성자산']
#    Top-10: ['sec2-2018-cf-현금흐름-재무활동현금흐름-1-단기차입금의순-감소-증가', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2016-cf-현금흐름-재무활동현금흐름-5-배당금의지급', 'sec2-2021-se-총포괄손익-1-당기순이익-총계', 'sec2-2021-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2016-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순증가', 'sec2-2020-se-총포괄손익-1-당기순이익-총계-69225d4f', 'sec2-2020-se-총포괄손익-1-당기순이익-이익잉여금-b0753bce']
#
# [45] Q045 | RR_avg=1.0000 | Q='2023년 순이익은 얼마인가?'
#    Gold: ['sec2-2023-is-당기순이익-당기순이익']
#    Top-10: ['sec2-2023-is-당기순이익-당기순이익', 'sec2-2023-ci-당기순이익', 'sec2-2023-is-매출액-매출액', 'sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-se-총포괄손익-1-당기순이익-이익잉여금-eb01ba6e', 'sec2-2023-cf-현금흐름-기말의현금및현금성자산-말의현금및현금성자산', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2023-is-주당이익-기본주당이익', 'sec2-2022-is-매출원가-매출원가']
#
# [46] Q046 | RR_avg=0.0000 | Q='2015년부터 2023년까지 순이익은 얼마인가?'
#    Gold: ['sec2-2015-ci-당기순이익', 'sec2-2016-ci-당기순이익', 'sec2-2017-ci-당기순이익', 'sec2-2018-ci-당기순이익', 'sec2-2019-ci-당기순이익', 'sec2-2020-ci-당기순이익', 'sec2-2021-ci-당기순이익', 'sec2-2022-ci-당기순이익', 'sec2-2023-ci-당기순이익']
#    Top-10: ['sec2-2015-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec2-2015-cf-현금흐름-재무활동현금흐름-3-자기주식의처분', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec2-2015-cf-현금흐름-투자활동현금흐름-자활동현금흐름', 'sec2-2016-se-총포괄손익-1-당기순이익-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가']
#
# [47] Q047 | RR_avg=0.0000 | Q='2021년과 2023년 부채와 자본 총계은 각각 얼마인가?'
#    Gold: ['sec2-2021-bs-root-부채와자본총계', 'sec2-2023-bs-root-부채와자본총계']
#    Top-10: ['sec2-2023-se-총포괄손익-1-당기순이익-총계-c8e3cfff', 'sec2-2024-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-se-총포괄손익-1-당기순이익-이익잉여금-eb01ba6e', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2023-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2023-is-매출총이익-판매비와관리비', 'sec2-2022-se-총포괄손익-1-당기순이익-총계-53b7d068', 'sec2-2023-se-총포괄손익-1-당기순이익-총계', 'sec2-2023-cf-현금흐름-영업활동현금흐름-당기순이익', 'sec2-2023-bs-부채-비유동부채-1-사채']
#
# [48] Q048 | RR_avg=0.0000 | Q='2015년부터 2023년까지 주식 발행 초과액은?'
#    Gold: ['sec2-2015-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2016-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2017-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2018-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2019-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2020-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2021-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2022-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2023-bs-자본-주식발행초과금-주식발행초과금']
#    Top-10: ['sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계-0547332d', 'sec1-2015-kam-none', 'sec2-2014-se-자본에직접인식된주주와의거래-2-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2016-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목', 'sec1-2014-kam-none', 'sec2-2014-se-자본에직접인식된주주와의거래-3-자기주식의처분-총계', 'sec2-2016-se-총포괄손익-1-당기순이익-총계']
#
# [49] Q049 | RR_avg=0.0000 | Q='2016년 자기 주식 매각액은?'
#    Gold: ['sec2-2016-cf-현금흐름-재무활동현금흐름-3-자기주식의처분']
#    Top-10: ['sec2-2017-se-총포괄손익-1-당기순이익-총계', 'sec2-2017-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2017-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2017-se-자본에직접인식된주주와의거래-3-자기주식의소각-기타자본항목', 'sec2-2016-se-총포괄손익-1-당기순이익-총계-4cf49de0', 'sec2-2016-se-총포괄손익-1-당기순이익-이익잉여금-d8f2c8f0', 'sec2-2019-se-자본에직접인식된주주와의거래-3-자기주식의소각-이익잉여금', 'sec2-2017-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec1-2016-kam-none', 'sec2-2019-se-총포괄손익-1-당기순이익-총계']
#
# [50] Q050 | RR_avg=0.0000 | Q='최근 5년 동안 선급금의 값은?'
#    Gold: ['sec2-2024-bs-자산-유동자산-6-선급금', 'sec2-2023-bs-자산-유동자산-6-선급금', 'sec2-2022-bs-자산-유동자산-5-선급금', 'sec2-2021-bs-자산-유동자산-5-선급금', 'sec2-2020-bs-자산-유동자산-5-선급금']
#    Top-10: ['sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-총계-32c787e4', 'sec2-2015-cf-현금흐름-재무활동현금흐름-2-자기주식의취득', 'sec2-2016-se-자본에직접인식된주주와의거래-2-자기주식의취득-총계', 'sec2-2015-se-자본에직접인식된주주와의거래-2-자기주식의취득-기타자본항목-5e429190', 'sec2-2016-se-자본에직접인식된주주와의거래-2-자기주식의취득-기타자본항목', 'sec2-2015-cf-현금흐름-재무활동현금흐름-4-사채의상환', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계-4da696b1', 'sec2-2014-cf-현금흐름-재무활동현금흐름-4-사채의상환', 'sec2-2019-cf-현금흐름-재무활동현금흐름-2-자기주식의취득', 'sec2-2015-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득']
#
# ================================================================================
# MRR_avg (over 50 questions, top-10) = 0.0729

# %%
import csv

output_csv = "../result/e5_raw_scores.csv"
with open(output_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["QuestionID", "RR_avg"])
    for idx, score in enumerate(scores, 1):
        writer.writerow([f"Q{idx:03d}", score])

# %% [markdown]
# ## json에서 line_item 추출 & 저장

# %%
import os, io, json

JSON_DIR = '../../json/'

def _strip_bom(s: str) -> str:
    return s[1:] if s and s[0] == "\ufeff" else s

def read_json_or_jsonl(path: str):
    """JSON/JSONL 모두 유연하게 읽기"""
    with open(path, "r", encoding="utf-8") as f:
        raw = _strip_bom(f.read()).strip()
    if not raw:
        return []
    if raw.startswith("["):
        return json.loads(raw)
    items = []
    for line in io.StringIO(raw):
        line = line.strip()
        if not line or line.startswith("//") or line.startswith("#"):
            continue
        if line.endswith(","):
            line = line[:-1]
        items.append(json.loads(line))
    return items

def collect_line_items(json_dir: str) -> set[str]:
    line_items = set()
    for fname in os.listdir(json_dir):
        if not fname.endswith(".jsonl"):
            continue
        fpath = os.path.join(json_dir, fname)
        items = read_json_or_jsonl(fpath)
        for rec in items:
            md = rec.get("metadata", {})
            li = md.get("line_item")
            if li:
                line_items.add(li.strip())
    return line_items

all_line_items = collect_line_items(JSON_DIR)

# %%
import re
import io
import json
import textwrap
from typing import List, Dict, Any, Optional
from FlagEmbedding import FlagReranker

# --------------------------------------------------------
# QA 파일 로더 (기존과 동일)
def read_qa(path: str) -> List[Dict[str, Any]]:
    def _strip_bom(s: str) -> str:
        return s[1:] if s and s[0] == "\ufeff" else s
    with open(path, "r", encoding="utf-8") as f:
        raw = _strip_bom(f.read()).strip()
    if raw.startswith("["):
        return json.loads(raw)
    items = []
    for line in io.StringIO(raw):
        line = line.strip()
        if not line or line.startswith("//") or line.startswith("#"):
            continue
        if line.endswith(","):
            line = line[:-1]
        items.append(json.loads(line))
    return items

# --------------------------------------------------------
# 연도/상대연도 파싱 (기존과 동일)
def extract_years_with_relative(text: str) -> list[int]:
    years = set()
    for y in re.findall(r"(19\d{2}|20\d{2})", text):
        years.add(int(y))
    base = max(years) if years else None
    if base:
        if any(x in text for x in ["전년","작년","전기","전분기"]):
            years.add(base - 1)
        if any(x in text for x in ["재작년","전전기","전전분기"]):
            years.add(base - 2)
        if any(x in text for x in ["올해","금년"]):
            years.add(base)
    return sorted(list(years))

# --------------------------------------------------------
# 질문에서 line_item 추출 (사전 처리 로직 추가)
try:
    LINE_ITEM_KEYWORDS = list(all_line_items) # set일 수 있으므로 list로 변환
except NameError:
    LINE_ITEM_KEYWORDS = []

LINE_ITEM_KEYWORDS.sort(key=len, reverse=True)
LINE_ITEM_KEYWORDS_NO_SPACE = [kw.replace(" ", "") for kw in LINE_ITEM_KEYWORDS]
LINE_ITEM_PAIRS = list(zip(LINE_ITEM_KEYWORDS, LINE_ITEM_KEYWORDS_NO_SPACE))

def extract_line_item(text: str) -> Optional[str]:
    text_no_space = text.replace(" ", "")
    for original_kw, kw_no_space in LINE_ITEM_PAIRS:
        if kw_no_space in text_no_space:
            return original_kw
    return None

# --------------------------------------------------------
# 리랭커 준비 (기존과 동일)
reranker = FlagReranker("BAAI/bge-reranker-v2-m3", use_fp16=True)

# --------------------------------------------------------
# Reciprocal Rank 계산 (기존과 동일)
def reciprocal_rank_avg(ranked_ids: list[str], gold_ids: list[str]) -> float:
    ranks = []
    for g in gold_ids:
        if g in ranked_ids:
            r = ranked_ids.index(g) + 1
            ranks.append(1.0 / r)
    if not ranks:
        return 0.0
    return sum(ranks) / len(gold_ids)

# --------------------------------------------------------
# ✅ (수정) 메인 평가 함수: 검색 로직 통합
def eval_mrr_avg_with_boosting(qa_path: str, max_samples: int = 50, top_k: int = 10, dense_k: int = 15):
    qa_items = read_qa(qa_path)
    total = len(qa_items)
    print(f"총 {total}개 QA 중 {max_samples}개 샘플 평가\n")

    scores = []
    for idx, item in enumerate(qa_items[:max_samples], 1):
        qid    = item.get("id")
        qtext  = item.get("question", "")
        golds  = item.get("answers", [])

        print("="*100)
        print(f"[{idx}] ID={qid}")
        print(f"Q: {qtext}")
        print(f"Gold IDs: {golds}")

        years = extract_years_with_relative(qtext)
        line_item = extract_line_item(qtext)

        candidates: list[tuple[str, str, dict]] = []
        
        # ✅ 쿼리 확장: line_item이 있으면 검색어에 추가하여 정확도 향상
        queries = [qtext]
        if line_item and years:
            for y in years:
                queries.append(f"{y}년 {line_item}")

        # ✅ 검색 로직 통합: line_item 유무에 관계없이 sec1, sec2 모두 검색
        for sub_q in queries:
            for cname in ["sec1", "sec2"]:
                try:
                    res = collections[cname].query(
                        query_texts=[sub_q],
                        n_results=dense_k,
                        include=["documents", "metadatas"],
                        where={"year": {"$in": years}} if years else None,
                    )
                    docs = res.get("documents", [[]])[0]
                    mds  = res.get("metadatas", [[]])[0]
                    ids  = res.get("ids", [[]])[0]
                    for doc, md, doc_id in zip(docs, mds, ids):
                        if not all([doc, md, doc_id]): continue
                        candidates.append((doc[:2000], doc_id, md))
                except Exception as e:
                    print(f"[WARN] {cname} '{sub_q}' query error: {e}")

        # 중복 후보 제거 (ID 기준)
        unique_candidates = []
        seen_ids = set()
        for doc, doc_id, md in candidates:
            if doc_id not in seen_ids:
                unique_candidates.append((doc, doc_id, md))
                seen_ids.add(doc_id)

        ranked_ids = []
        if unique_candidates:
            # 리랭커 점수 계산
            rerank_candidates = [(doc, doc_id) for doc, doc_id, md in unique_candidates]
            pairs = [[qtext, c[0]] for c in rerank_candidates]
            scores_reranker = reranker.compute_score(pairs, normalize=True, batch_size=32)

            # 하이브리드 리랭킹: line_item 일치 시 보너스 점수 부여
            final_ranked_items = []
            for (doc_text, doc_id, md), score in zip(unique_candidates, scores_reranker):
                bonus = 0.0
                if line_item and md.get("line_item") == line_item:
                    bonus = 0.1
                
                final_ranked_items.append({
                    "id": doc_id,
                    "final_score": score + bonus
                })
            
            final_ranked_items.sort(key=lambda x: x["final_score"], reverse=True)
            ranked_ids = [item["id"] for item in final_ranked_items[:top_k]]

        rr_avg = reciprocal_rank_avg(ranked_ids, golds)
        scores.append(rr_avg)

        print(f" → RR_avg={rr_avg:.4f}")
        print(f"   Ranked IDs: {ranked_ids}")
        print()

    mrr_avg = sum(scores) / len(scores) if scores else 0.0
    print("="*80)
    print(f"MRR_avg (over {len(scores)} questions, top-{top_k}) = {mrr_avg:.4f}")

    return mrr_avg, scores

# --------------------------------------------------------
# 실행
QA_PATH = "../../qa_dataset_50_revised.jsonl"
mrr_value, scores = eval_mrr_avg_with_boosting(QA_PATH, max_samples=50, top_k=10, dense_k=8)
# Out:
# 총 50개 QA 중 50개 샘플 평가
#
# ====================================================================================================
# [1] ID=Q001
# Q: 2019년 감사보고서를 담당한 회계 감사 기관은 어디인가?
# Gold IDs: ['sec1-2019-auditor']
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#  → RR_avg=1.0000
#    Ranked IDs: ['sec1-2019-auditor', 'sec1-2019-kam-2', 'sec1-2019-kam-1', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-기타자본항목-b6143e85', 'sec2-2019-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-기타자본항목-f5ba8a2d', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계-4da696b1', 'sec2-2019-cf-현금흐름-투자활동현금흐름-4-기타포괄손익공정가치금융자산의처분', 'sec2-2019-is-법인세비용차감전순이익-법인세비용', 'sec2-2019-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2019-bs-부채-유동부채-5-예수금']
#
# ====================================================================================================
# [2] ID=Q002
# Q: 2020년 감사를 담당한 곳은?
# Gold IDs: ['sec1-2020-auditor']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec1-2020-auditor', 'sec1-2020-kam-1', 'sec2-2020-cf-현금흐름-재무활동현금흐름-3-배당금의지급', 'sec2-2020-cf-현금흐름-영업활동현금흐름-2-이자의수취', 'sec2-2020-ci-기타포괄손익', 'sec2-2020-cf-현금흐름-투자활동현금흐름-3-기타포괄손익공정가치금융자산의처분', 'sec2-2020-cf-현금흐름-투자활동현금흐름-4-기타포괄손익공정가치금융자산의취득', 'sec2-2020-bs-자본-기타자본항목-기타자본항목', 'sec2-2020-is-영업이익-기타수익', 'sec2-2020-bs-부채-유동부채-4-선수금']
#
# ====================================================================================================
# [3] ID=Q003
# Q: 2023년 핵심감사사항은?
# Gold IDs: ['sec1-2023-kam-1']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec1-2023-kam-1', 'sec1-2023-kam-2', 'sec1-2023-auditor', 'sec2-2023-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2023-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2023-is-주당이익-기본주당이익', 'sec2-2023-is-주당이익-희석주당이익', 'sec2-2023-bs-자산-유동자산-4-미수금', 'sec2-2023-bs-자산-유동자산-5-선급비용', 'sec2-2023-bs-자산-비유동자산-6-순확정급여자산']
#
# ====================================================================================================
# [4] ID=Q004
# Q: 2018년 재화의 판매 관련 매출장려활동이 핵심감사사항으로 결정된 이유는?
# Gold IDs: ['sec1-2018-kam-1']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec1-2018-kam-1', 'sec1-2018-kam-2', 'sec2-2018-is-매출총이익-판매비와관리비', 'sec1-2018-auditor', 'sec2-2018-cf-현금흐름-투자활동현금흐름-4-장기매도가능금융자산의처분', 'sec2-2018-cf-현금흐름-투자활동현금흐름-5-장기매도가능금융자산의취득', 'sec2-2018-cf-현금흐름-영업활동현금흐름-3-이자의지급', 'sec2-2018-cf-현금흐름-현금및현금성자산의감소-현금및현금성자산의감소', 'sec2-2018-se-자본에직접인식된주주와의거래-회계정책변경누적효과-이익잉여금', 'sec2-2018-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순-증가-감소']
#
# ====================================================================================================
# [5] ID=Q005
# Q: 2019년 감가상각 개시 시점의 적절성이 왜 핵심감사사항?
# Gold IDs: ['sec1-2019-kam-1']
#  → RR_avg=0.5000
#    Ranked IDs: ['sec1-2019-kam-2', 'sec1-2019-kam-1', 'sec1-2019-auditor', 'sec2-2019-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2019-bs-자산-유동자산-6-선급비용', 'sec2-2019-se-총포괄손익-3-순확정급여자산재측정요소-총계-4da696b1', 'sec2-2019-bs-부채-유동부채-7-당기법인세부채', 'sec2-2019-bs-부채-비유동부채-1-사채', 'sec2-2019-bs-자산-유동자산-4-미수금']
#
# ====================================================================================================
# [6] ID=Q006
# Q: 2016년 투자 활동에 따른 현금 흐름은 얼마인가?
# Gold IDs: ['sec2-2016-cf-현금흐름-투자활동현금흐름-자활동현금흐름']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2016-cf-현금흐름-투자활동현금흐름-자활동현금흐름', 'sec2-2016-cf-현금흐름-투자활동현금흐름-13-현금의기타유입', 'sec2-2016-cf-현금흐름-투자활동현금흐름-10-유형자산의취득', 'sec2-2016-cf-현금흐름-투자활동현금흐름-7-종속기업-관계기업및공동기업투자의처분', 'sec2-2016-cf-현금흐름-투자활동현금흐름-9-유형자산의처분', 'sec2-2016-cf-현금흐름-투자활동현금흐름-8-종속기업-관계기업및공동기업투자의취득', 'sec2-2016-cf-현금흐름-투자활동현금흐름-11-무형자산의처분', 'sec2-2016-cf-현금흐름-영업활동현금흐름-조정', 'sec1-2016-auditor', 'sec1-2016-kam-none']
#
# ====================================================================================================
# [7] ID=Q007
# Q: 2014년과 2015년 단기 매도 가능한 금융자산은 얼마인가?
# Gold IDs: ['sec2-2014-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2015-bs-자산-유동자산-3-단기매도가능금융자산']
#  → RR_avg=0.7500
#    Ranked IDs: ['sec2-2014-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2015-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2015-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2014-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의순감소', 'sec2-2014-bs-자산-비유동자산-1-장기매도가능금융자산', 'sec2-2015-bs-자산-비유동자산-1-장기매도가능금융자산', 'sec2-2014-bs-자산-유동자산-2-단기금융상품', 'sec2-2015-bs-자산-유동자산-2-단기금융상품', 'sec1-2014-kam-none', 'sec1-2015-kam-none']
#
# ====================================================================================================
# [8] ID=Q008
# Q: 2016년 사채은 얼마인가?
# Gold IDs: ['sec2-2016-bs-부채-비유동부채-1-사채']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2016-bs-부채-비유동부채-1-사채', 'sec2-2016-bs-부채-부채총계', 'sec2-2016-cf-현금흐름-재무활동현금흐름-4-사채의상환', 'sec2-2016-bs-부채-유동부채-5-예수금', 'sec2-2016-bs-부채-유동부채-4-선수금', 'sec2-2016-bs-부채-유동부채-10-기타유동부채', 'sec2-2016-bs-부채-유동부채-1-매입채무', 'sec2-2016-bs-부채-유동부채-8-유동성장기부채', 'sec2-2016-bs-부채-비유동부채-3-장기충당부채', 'sec2-2016-bs-부채-비유동부채-4-기타비유동부채']
#
# ====================================================================================================
# [9] ID=Q009
# Q: 2016년과 2024년 법인세 비용 차감 전 순이익은 얼마인가?
# Gold IDs: ['sec2-2016-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2024-is-법인세비용차감전순이익-법인세비용차감전순이익']
#  → RR_avg=0.6667
#    Ranked IDs: ['sec2-2024-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2024-is-법인세비용차감전순이익-법인세비용', 'sec2-2016-is-법인세비용차감전순이익-법인세비용차감전순이익', 'sec2-2016-is-법인세비용차감전순이익-법인세비용', 'sec2-2024-ci-당기순이익', 'sec2-2024-is-당기순이익-당기순이익', 'sec2-2024-cf-현금흐름-영업활동현금흐름-5-법인세납부액', 'sec2-2024-bs-자산-비유동자산-7-이연법인세자산', 'sec2-2024-se-총포괄손익-3-순확정급여부채재측정요소-총계-11fece6f', 'sec2-2016-cf-현금흐름-영업활동현금흐름-5-법인세납부액']
#
# ====================================================================================================
# [10] ID=Q010
# Q: 2014년과 2015년 미수금은 각각 얼마인가?
# Gold IDs: ['sec2-2014-bs-자산-유동자산-5-미수금', 'sec2-2015-bs-자산-유동자산-5-미수금']
#  → RR_avg=0.7500
#    Ranked IDs: ['sec2-2014-bs-자산-유동자산-5-미수금', 'sec2-2015-bs-자산-유동자산-5-미수금', 'sec2-2014-bs-부채-유동부채-3-미지급금', 'sec2-2015-bs-부채-유동부채-3-미지급금', 'sec2-2014-bs-부채-비유동부채-2-장기미지급금', 'sec2-2014-bs-부채-유동부채-6-미지급비용', 'sec2-2015-bs-부채-비유동부채-2-장기미지급금', 'sec2-2015-bs-부채-유동부채-6-미지급비용', 'sec2-2014-bs-부채-유동부채-7-미지급법인세', 'sec2-2014-bs-부채-유동부채-4-선수금']
#
# ====================================================================================================
# [11] ID=Q011
# Q: 2019년부터 2024년까지의 기타수익은 얼마인가?
# Gold IDs: ['sec2-2019-is-영업이익-기타수익', 'sec2-2020-is-영업이익-기타수익', 'sec2-2021-is-영업이익-기타수익', 'sec2-2022-is-영업이익-기타수익', 'sec2-2023-is-영업이익-손실-기타수익', 'sec2-2024-is-영업이익-손실-기타수익']
#  → RR_avg=0.2083
#    Ranked IDs: ['sec2-2024-is-영업이익-손실-기타수익', 'sec2-2024-is-영업이익-손실-기타비용', 'sec2-2024-ci-기타포괄손익', 'sec2-2019-is-영업이익-기타수익', 'sec2-2024-bs-자산-유동자산-7-기타유동자산', 'sec2-2024-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-기타자본항목-f2ed9fac', 'sec2-2024-bs-자본-기타자본항목-기타자본항목', 'sec2-2024-bs-자산-비유동자산-1-기타포괄손익공정가치금융자산', 'sec2-2024-bs-자산-비유동자산-8-기타비유동자산', 'sec2-2024-se-총포괄손익-3-순확정급여부채재측정요소-기타자본항목-6c4b9b36']
#
# ====================================================================================================
# [12] ID=Q012
# Q: 2024년 말 이익잉여금은 얼마인가?
# Gold IDs: ['sec2-2024-bs-자본-이익잉여금-이익잉여금']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2024-bs-자본-이익잉여금-이익잉여금', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금-80261615', 'sec2-2024-se-자본에직접인식된주주와의거래-1-배당-이익잉여금-99b9a9ba', 'sec2-2024-se-총포괄손익-2-기타포괄손익공정가치금융자산평가손익-이익잉여금-ed8a169f', 'sec2-2024-se-총포괄손익-1-당기순이익-이익잉여금', 'sec2-2024-se-자본에직접인식된주주와의거래-1-배당-이익잉여금', 'sec2-2024-is-주당이익-기본주당이익', 'sec2-2024-is-주당이익-희석주당이익', 'sec2-2024-bs-자산-유동자산-4-미수금', 'sec1-2024-auditor']
#
# ====================================================================================================
# [13] ID=Q013
# Q: 2014년부터 2019년까지 단기 금융 상품의 순감소 또는 증가는 얼마인가?
# Gold IDs: ['sec2-2014-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2017-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2019-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가']
#  → RR_avg=0.5000
#    Ranked IDs: ['sec2-2014-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2019-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2014-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의순감소', 'sec2-2014-bs-자산-유동자산-2-단기금융상품', 'sec2-2019-bs-자산-유동자산-2-단기금융상품', 'sec2-2019-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2014-cf-현금흐름-현금및현금성자산의감소-현금및현금성자산의감소', 'sec2-2014-bs-자산-유동자산-3-단기매도가능금융자산', 'sec2-2019-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2014-cf-현금흐름-재무활동현금흐름-1-단기차입금의순차입-상환']
#
# ====================================================================================================
# [14] ID=Q014
# Q: 최근 6년 동안 희석 주당 이익의 값은?
# Gold IDs: ['sec2-2024-is-주당이익-희석주당이익', 'sec2-2023-is-주당이익-희석주당이익', 'sec2-2022-is-주당이익-희석주당이익', 'sec2-2021-is-주당이익-희석주당이익', 'sec2-2020-is-주당이익-희석주당이익', 'sec2-2019-is-주당이익-희석주당이익']
#  → RR_avg=0.1236
#    Ranked IDs: ['sec2-2014-is-주당이익-희석주당이익', 'sec2-2016-is-주당이익-희석주당이익', 'sec2-2015-is-주당이익-희석주당이익', 'sec2-2019-is-주당이익-희석주당이익', 'sec2-2022-is-주당이익-희석주당이익', 'sec2-2021-is-주당이익-희석주당이익', 'sec2-2018-is-주당이익-희석주당이익', 'sec2-2020-is-주당이익-희석주당이익', 'sec1-2019-kam-2', 'sec1-2023-kam-1']
#
# ====================================================================================================
# [15] ID=Q015
# Q: 2024년 예수금액은?
# Gold IDs: ['sec2-2024-bs-부채-유동부채-5-예수금']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2024-bs-부채-유동부채-5-예수금', 'sec2-2024-bs-자산-유동자산-4-미수금', 'sec2-2024-bs-부채-유동부채-4-선수금', 'sec2-2024-is-주당이익-희석주당이익', 'sec2-2024-is-주당이익-기본주당이익', 'sec2-2024-cf-현금흐름-외화환산으로인한현금의변동-화환산으로인한현금의변동', 'sec2-2024-is-당기순이익-당기순이익', 'sec2-2024-ci-당기순이익', 'sec2-2024-bs-자본-이익잉여금-이익잉여금', 'sec2-2024-ci-총포괄손익']
#
# ====================================================================================================
# [16] ID=Q016
# Q: 2017년 사채의 상환은 얼마인가?
# Gold IDs: ['sec2-2017-cf-현금흐름-재무활동현금흐름-3-사채의상환']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2017-cf-현금흐름-재무활동현금흐름-3-사채의상환', 'sec2-2017-bs-부채-비유동부채-1-사채', 'sec2-2017-bs-부채-부채총계', 'sec2-2017-bs-부채-유동부채-2-단기차입금', 'sec2-2017-bs-부채-유동부채-4-선수금', 'sec2-2017-bs-부채-비유동부채-비유동부채', 'sec2-2017-bs-부채-유동부채-9-충당부채', 'sec2-2017-bs-부채-비유동부채-3-장기충당부채', 'sec2-2017-bs-부채-유동부채-1-매입채무', 'sec2-2017-bs-부채-유동부채-8-유동성장기부채']
#
# ====================================================================================================
# [17] ID=Q017
# Q: 2016년 무형 자산의 구매는 얼마인가?
# Gold IDs: ['sec2-2016-cf-현금흐름-투자활동현금흐름-12-무형자산의취득']
#  → RR_avg=0.5000
#    Ranked IDs: ['sec2-2016-bs-자산-비유동자산-4-무형자산', 'sec2-2016-cf-현금흐름-투자활동현금흐름-12-무형자산의취득', 'sec2-2016-cf-현금흐름-투자활동현금흐름-11-무형자산의처분', 'sec2-2016-bs-자산-비유동자산-3-유형자산', 'sec2-2016-bs-자산-유동자산-9-기타유동자산', 'sec2-2016-bs-자산-유동자산-2-단기금융상품', 'sec2-2016-bs-자산-비유동자산-1-장기매도가능금융자산', 'sec2-2016-cf-현금흐름-투자활동현금흐름-6-장기매도가능금융자산의취득', 'sec2-2016-bs-자산-유동자산-3-단기매도가능금융자산', 'sec1-2016-kam-none']
#
# ====================================================================================================
# [18] ID=Q018
# Q: 2020년 조정 금액은?
# Gold IDs: ['sec2-2020-cf-현금흐름-영업활동현금흐름-조정']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2020-cf-현금흐름-영업활동현금흐름-조정', 'sec2-2020-cf-현금흐름-외화환산으로인한현금의변동-화환산으로인한현금의변동', 'sec2-2020-cf-현금흐름-현금및현금성자산의증가-감소-현금및현금성자산의증가-감소', 'sec2-2020-bs-자산-비유동자산-6-순확정급여자산', 'sec2-2020-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가-감소', 'sec2-2020-bs-자산-유동자산-5-선급비용', 'sec2-2020-bs-자본-기타자본항목-기타자본항목', 'sec2-2020-bs-자산-비유동자산-1-기타포괄손익공정가치금융자산', 'sec2-2020-bs-자산-비유동자산-2-당기손익공정가치금융자산', 'sec2-2020-bs-자산-비유동자산-4-유형자산']
#
# ====================================================================================================
# [19] ID=Q019
# Q: 2014년부터 2024년까지 선수금은 얼마인가?
# Gold IDs: ['sec2-2014-bs-부채-유동부채-4-선수금', 'sec2-2015-bs-부채-유동부채-4-선수금', 'sec2-2016-bs-부채-유동부채-4-선수금', 'sec2-2017-bs-부채-유동부채-4-선수금', 'sec2-2018-bs-부채-유동부채-4-선수금', 'sec2-2019-bs-부채-유동부채-4-선수금', 'sec2-2020-bs-부채-유동부채-4-선수금', 'sec2-2021-bs-부채-유동부채-4-선수금', 'sec2-2022-bs-부채-유동부채-4-선수금', 'sec2-2023-bs-부채-유동부채-4-선수금', 'sec2-2024-bs-부채-유동부채-4-선수금']
#  → RR_avg=0.1364
#    Ranked IDs: ['sec2-2024-bs-부채-유동부채-4-선수금', 'sec2-2014-bs-부채-유동부채-4-선수금', 'sec2-2024-bs-자본-자본금-1-우선주자본금', 'sec2-2024-bs-자산-유동자산-4-미수금', 'sec2-2024-is-주당이익-기본주당이익', 'sec2-2024-bs-자본-자본금-2-보통주자본금', 'sec2-2024-bs-자본-자본금-자본금', 'sec2-2024-bs-자본-이익잉여금-이익잉여금', 'sec2-2014-bs-자산-유동자산-6-선급금', 'sec2-2014-bs-자본-자본금-1-우선주자본금']
#
# ====================================================================================================
# [20] ID=Q020
# Q: 2020년 유동성 장기 채무는 얼마인가?
# Gold IDs: ['sec2-2020-bs-부채-유동부채-8-유동성장기부채']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2020-bs-부채-유동부채-8-유동성장기부채', 'sec2-2020-bs-부채-유동부채-유동부채', 'sec2-2020-bs-부채-비유동부채-2-장기차입금', 'sec2-2020-bs-부채-비유동부채-3-장기미지급금', 'sec2-2020-bs-부채-유동부채-1-매입채무', 'sec2-2020-bs-부채-유동부채-2-단기차입금', 'sec2-2020-bs-부채-유동부채-3-미지급금', 'sec2-2020-bs-부채-유동부채-6-미지급비용', 'sec1-2020-auditor', 'sec1-2020-kam-1']
#
# ====================================================================================================
# [21] ID=Q021
# Q: 2022년 매입 채무는 얼마인가?
# Gold IDs: ['sec2-2022-bs-부채-유동부채-1-매입채무']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2022-bs-부채-유동부채-1-매입채무', 'sec2-2022-bs-부채-유동부채-2-단기차입금', 'sec2-2022-bs-부채-비유동부채-2-장기차입금', 'sec2-2022-bs-부채-비유동부채-비유동부채', 'sec2-2022-bs-부채-비유동부채-1-사채', 'sec2-2022-bs-부채-유동부채-4-선수금', 'sec2-2022-bs-부채-유동부채-3-미지급금', 'sec2-2022-bs-부채-유동부채-6-미지급비용', 'sec2-2022-bs-부채-비유동부채-3-장기미지급금', 'sec2-2022-cf-현금흐름-재무활동현금흐름-2-사채및장기차입금의상환']
#
# ====================================================================================================
# [22] ID=Q022
# Q: 2015년부터 2017년까지 단기 차입금 증가액은?
# Gold IDs: ['sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2016-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2017-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가']
#  → RR_avg=0.5000
#    Ranked IDs: ['sec2-2017-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2015-cf-현금흐름-재무활동현금흐름-1-단기차입금의순증가', 'sec2-2017-bs-부채-유동부채-2-단기차입금', 'sec2-2015-bs-부채-유동부채-2-단기차입금', 'sec2-2017-bs-자산-유동자산-2-단기금융상품', 'sec2-2017-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순감소-증가', 'sec2-2015-bs-자산-유동자산-2-단기금융상품', 'sec2-2015-cf-현금흐름-투자활동현금흐름-1-단기금융상품의순-증가-감소', 'sec2-2015-cf-현금흐름-투자활동현금흐름-2-단기매도가능금융자산의처분', 'sec2-2015-bs-자산-유동자산-3-단기매도가능금융자산']
#
# ====================================================================================================
# [23] ID=Q023
# Q: 2015년 보통주 자본금은 얼마인가?
# Gold IDs: ['sec2-2015-bs-자본-자본금-2-보통주자본금']
#  → RR_avg=1.0000
#    Ranked IDs: ['sec2-2015-bs-자본-자본금-2-보통주자본금', 'sec2-2015-bs-자본-자본금-1-우선주자본금', 'sec2-2015-bs-자본-자본금-자본금', 'sec2-2015-bs-자본-자본총계', 'sec2-2015-bs-자본-주식발행초과금-주식발행초과금', 'sec2-2015-bs-자본-기타자본항목-기타자본항목', 'sec2-2015-bs-자본-이익잉여금-이익잉여금', 'sec2-2015-bs-root-부채와자본총계', 'sec2-2015-se-자본에직접인식된주주와의거래-3-자기주식의처분-기타자본항목-813fc593', 'sec2-2015-is-주당이익-기본주당이익']
#
# ====================================================================================================
# [24] ID=Q024
# Q: 2016년과 2021년 재고자산은 각각 얼마인가?
# Gold IDs: ['sec2-2016-bs-자산-유동자산-8-재고자산', 'sec2-2021-bs-자산-유동자산-6-재고자산']
#  → RR_avg=0.7500
#    Ranked IDs: ['sec2-2021-bs-자산-유동자산-6-재고자산', 'sec2-2016-bs-자산-유동자산-8-재고자산', 'sec2-2016-bs-자산-유동자산-유동자산', 'sec2-2016-bs-자산-유동자산-1-현금및현금성자산', 'sec2-2021-bs-자산-유동자산-7-기타유동자산', 'sec2-2016-bs-자산-유동자산-9-기타유동자산', 'sec2-2021-bs-자산-유동자산-1-현금및현금성자산', 'sec2-2016-bs-자산-유동자산-10-매각예정분류자산', 'sec2-2016-bs-자산-유동자산-5-미수금', 'sec2-2016-bs-자산-비유동자산-1-장기매도가능금융자산']
#
# ====================================================================================================
# [25] ID=Q025
# Q: 최근 5년 동안 장기 금융 상품의 취득의 값은?
# Gold IDs: ['sec2-2024-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득', 'sec2-2023-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2022-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2021-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2020-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득']
#  → RR_avg=0.0000
#    Ranked IDs: ['sec2-2016-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2017-cf-현금흐름-투자활동현금흐름-4-장기금융상품의취득', 'sec2-2018-cf-현금흐름-투자활동현금흐름-3-장기금융상품의취득', 'sec2-2015-cf-현금흐름-투자활동현금흐름-7-장기매도가능금융자산의취득', 'sec2-2015-cf-현금흐름-투자활동현금흐름-5-장기금융상품의취득', 'sec2-2015-cf-현금흐름-투자활동현금흐름-4-장기금융상품의처분', 'sec2-2015-bs-자산-비유동자산-1-장기매도가능금융자산', 'sec2-2015-cf-현금흐름-투자활동현금흐름-6-장기매도가능금융자산의처분', 'sec1-2019-kam-2', 'sec1-2018-kam-2']
#
# ====================================================================================================
# [26] ID=Q026
# Q: 최근 10년 동안 유동 부채의 값은?
# Gold IDs: ['sec2-2014-bs-부채-유동부채-유동부채', 'sec2-2015-bs-부채-유동부채-유동부채', 'sec2-2016-bs-부채-유동부채-유동부채', 'sec2-2017-bs-부채-유동부채-유동부채', 'sec2-2018-bs-부채-유동부채-유동부채', 'sec2-2019-bs-부채-유동부채-유동부채', 'sec2-2020-bs-부채-유동부채-유동부채', 'sec2-2021-bs-부채-유동부채-유동부채', 'sec2-2022-bs-부채-유동부채-유동부채', 'sec2-2023-bs-부채-유동부채-유동부채']
#  → RR_avg=0.1500
#    Ranked IDs: ['sec2-2017-bs-부채-유동부채-유동부채', 'sec2-2020-bs-부채-유동부채-유동부채', 'sec2-2014-bs-부채-유동부채-8-유동성사채', 'sec2-2017-bs-부채-유동부채-8-유동성장기부채', 'sec2-2016-bs-부채-유동부채-8-유동성장기부채', 'sec2-2020-bs-부채-유동부채-10-기타유동부채', 'sec2-2018-bs-부채-유동부채-8-유동성장기부채', 'sec2-2018-bs-부채-유동부채-10-기타유동부채', 'sec1-2018-kam-2', 'sec1-2019-kam-2']
#
# ====================================================================================================
# [27] ID=Q027
# Q: 2023년과 2024년 단기 금융 상품은 각각 얼마인가?
# Gold IDs: ['sec2-2023-bs-자산-유동자산-2-단기금융상품', 'sec2-2024-bs-자산-유동자산-2-단기금융상품']

# %%
import csv

output_csv = "../result/e5_scores.csv"
with open(output_csv, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["QuestionID", "RR_avg"])
    for idx, score in enumerate(scores, 1):
        writer.writerow([f"Q{idx:03d}", score])
